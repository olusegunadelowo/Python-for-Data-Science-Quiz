# %% [markdown]
# <a href="https://colab.research.google.com/github/olusegunadelowo/Python-for-Data-Science-Quiz/blob/main/Python_DS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#importing the dataset from google drive
import pandas as pd

# %%
df = pd.read_csv("/content/gdrive/MyDrive/Data Science Projects/hamoyeInternship/Python_ML-DS/FoodBalanceSheets_E_Africa_NOFLAG.csv", encoding='latin-1')
df.head(3)
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
#
#                          Element             Unit    Y2014    Y2015    Y2016  \
# 0  Total Population - Both sexes     1000 persons  38924.0  39728.0  40551.0
# 1       Domestic supply quantity      1000 tonnes      0.0      0.0      0.0
# 2  Food supply (kcal/capita/day)  kcal/capita/day   3377.0   3379.0   3372.0
#
#      Y2017    Y2018
# 0  41389.0  42228.0
# 1      0.0      0.0
# 2   3341.0   3322.0

# %%
#Q4. Perform a groupby operation on ‘Element’.  What is the total number of the sum of Processing in 2017?
df.groupby("Element")["Y2017"].sum()
# Out:
# Element
# Domestic supply quantity                  2088198.10
# Export Quantity                            182338.80
# Fat supply quantity (g/capita/day)          10253.84
# Feed                                       223705.68
# Food                                      1258888.28
# Food supply (kcal/capita/day)              454681.00
# Food supply quantity (kg/capita/yr)         48690.04
# Import Quantity                            294559.09
# Losses                                     160614.00
# Other uses (non-food)                       91645.97
# Processing                                 292836.00
# Production                                2030056.89
# Protein supply quantity (g/capita/day)      11842.45
# Residuals                                   35500.00
# Seed                                        24870.14
# Stock Variation                             54316.91
# Total Population - Both sexes             1112641.00
# Tourist consumption                            91.00
# ...

# %%
#Q9. Which year had the least correlation with ‘Element Code’?
import seaborn as sns
corr = df.corr()
sns.heatmap(corr)

#corr = df_train.select_dtypes("number").drop(columns = "price[USD]").corr() #dropped target variable "price[USD]" first
# Out:
# <ipython-input-32-748769ccd350>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()
# <Axes: >

# %%
#Q11. What is the total Protein supply quantity in Madagascar in 2015?
df.groupby(["Area","Element"])["Y2015"].sum()
# Out:
# Area      Element
# Algeria   Domestic supply quantity                  85972.86
#           Export Quantity                            1104.62
#           Fat supply quantity (g/capita/day)          317.40
#           Feed                                      10308.00
#           Food                                      61693.49
#                                                       ...
# Zimbabwe  Protein supply quantity (g/capita/day)      175.31
#           Residuals                                  -780.00
#           Seed                                        128.00
#           Stock Variation                            -343.00
#           Total Population - Both sexes             13815.00
# Name: Y2015, Length: 803, dtype: float64

# %%
#13. What is the total number of unique countries in the dataset?

df['Area'].nunique()
# Out:
# 49

# %%
#14. Select columns ‘Y2017’ and ‘Area’, Perform a groupby operation on ‘Area’.  Which of these Areas had the 7th lowest sum in 2017?
df.groupby("Area")["Y2017"].sum().sort_values(ascending=True)
# Out:
# Area
# Sudan (former)                       0.00
# Ethiopia PDR                         0.00
# Comoros                             59.84
# Seychelles                         442.34
# Sao Tome and Principe            12662.63
# Cabo Verde                       14650.74
# Guinea-Bissau                    19102.77
# Lesotho                          21267.96
# Botswana                         22101.30
# Djibouti                         22729.91
# Gambia                           23154.18
# Gabon                            27979.64
# Liberia                          29342.20
# Namibia                          29874.89
# Central African Republic         29937.00
# Congo                            41181.68
# Togo                             49841.88
# Mauritius                        51114.83
# Eswatini                         54343.33
# Sierra Leone                     55311.33
# Chad                             71594.68
# Rwanda                           73663.69
# ...

# %%
 #16. Select columns ‘Y2017’ and ‘Area’, Perform a groupby operation on ‘Area’. Which of these Areas had the highest sum in 2017?
df.groupby("Area")["Y2017"].sum().sort_values(ascending=False)
# Out:
# Area
# Nigeria                        1483268.23
# Egypt                           866379.92
# South Africa                    517590.54
# Ethiopia                        448683.76
# Morocco                         388495.36
# Ghana                           337599.06
# Algeria                         325644.27
# United Republic of Tanzania     322616.85
# Kenya                           264660.66
# Sudan                           239931.92
# Cameroon                        232030.43
# Angola                          229159.57
# Côte d'Ivoire                   224599.01
# Uganda                          213950.38
# Malawi                          181098.71
# Mozambique                      161407.98
# Mauritania                      156665.46
# Mali                            149928.33
# Madagascar                      131197.73
# Niger                           126707.58
# Benin                           124771.22
# Tunisia                         124167.20
# ...

# %%
#17. What is the total number and percentage of missing data in 2014 to 3 decimal places?
df["Y2014"].isna().sum()
# Out:
# 1589

# %%
#18. Perform a groupby operation on ‘Element’.  What year has the highest sum of Stock Variation?
df.groupby(["Element","Y2014","Y2015", "Y2016",	"Y2017",	"Y2018"])["Element"].count()
# Out:
# Element                   Y2014   Y2015   Y2016   Y2017   Y2018
# Domestic supply quantity  -133.0  -122.0  -167.0  -144.0  -148.0    1
#                           -130.0  -118.0  -164.0  -140.0  -143.0    1
#                           -46.0   -6.0    -17.0   -30.0   -89.0     1
#                           -27.0    48.0   -43.0   -47.0    76.0     2
#                           -25.0   -2.0    -12.0   -9.0    -175.0    1
#                                                                    ..
# Tourist consumption        21.0    18.0    2.0     2.0     2.0      1
#                            24.0    21.0    2.0     2.0     2.0      1
#                            34.0    27.0    2.0     2.0     2.0      1
#                            45.0    38.0    3.0     3.0     3.0      1
#                            62.0    48.0    4.0     4.0     4.0      1
# Name: Element, Length: 27430, dtype: int64

# %%
df["Y2014"].isnull
# Out:
# <bound method Series.isnull of 0        38924.00
# 1            0.00
# 2         3377.00
# 3           94.90
# 4           80.06
#            ...
# 60938       42.00
# 60939        3.06
# 60940        3.00
# 60941        0.10
# 60942        0.04
# Name: Y2014, Length: 60943, dtype: float64>

# %%
df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]
col = ["Age","Nationality","Overall"]
index = [1,2,3]
pd.DataFrame(lst, col, index)
# Out:
#               1          2   3
# Age          35   Portugal  94
# Nationality  33  Argentina  93
# Overall      30     Brazil  92

# %%
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]
col = ["Age","Nationality","Overall"]
index = ([i for i in range(1,4)])
pd.DataFrame(lst, col, index)
# Out:
#               1          2   3
# Age          35   Portugal  94
# Nationality  33  Argentina  93
# Overall      30     Brazil  92
